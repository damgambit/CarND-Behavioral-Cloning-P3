# %% [markdown]
# # Various Imports

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import keras
import pandas as pd
import cv2
import matplotlib.image as mpimg
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Load Data

# %%
data = pd.read_csv('data1/driving_log.csv', 
                   sep=',', 
                   error_bad_lines=False, 
                   header=None,
                   names=["Center", "Left", "Right", "Steering Angle", "Throttle", "Brake","Speed", "cc"])

data["Steering Angle"] = data["Steering Angle"].astype(float)

# %% [markdown]
# ## Fix random commas

# %%
def fix_speed(row):
    row[6] = float(str(row[6]) + '.' + str(row[7]))
    return row

data = data.apply(fix_speed, axis=1)

# %%
data.head()
# Out:
#                                               Center  \
# 0  /home/ramdoot/MachineLearning/CarND-Behavioral...
# 1  /home/ramdoot/MachineLearning/CarND-Behavioral...
# 2  /home/ramdoot/MachineLearning/CarND-Behavioral...
# 3  /home/ramdoot/MachineLearning/CarND-Behavioral...
# 4  /home/ramdoot/MachineLearning/CarND-Behavioral...
#
#                                                 Left  \
# 0  /home/ramdoot/MachineLearning/CarND-Behavioral...
# 1  /home/ramdoot/MachineLearning/CarND-Behavioral...
# 2  /home/ramdoot/MachineLearning/CarND-Behavioral...
# 3  /home/ramdoot/MachineLearning/CarND-Behavioral...
# 4  /home/ramdoot/MachineLearning/CarND-Behavioral...
#
#                                                Right  Steering Angle  \
# 0  /home/ramdoot/MachineLearning/CarND-Behavioral...             0.0
# 1  /home/ramdoot/MachineLearning/CarND-Behavioral...             0.0
# 2  /home/ramdoot/MachineLearning/CarND-Behavioral...             0.0
# 3  /home/ramdoot/MachineLearning/CarND-Behavioral...             0.0
# 4  /home/ramdoot/MachineLearning/CarND-Behavioral...             0.0
#
#    Throttle  Brake     Speed     cc
# 0         1      0  30.19029  19029
# 1         1      0  30.19029  19029
# 2         1      0  30.19029  19029
# 3         1      0  30.19030   1903
# 4         1      0  30.19031  19031

# %%
data.describe()
# Out:
#        Steering Angle      Throttle         Brake         Speed            cc
# count          3416.0  3.416000e+03  3.416000e+03  3.416000e+03  3.416000e+03
# mean              0.0  3.865112e+06  1.474593e+04  5.515664e+05  2.397294e+04
# std               0.0  2.754580e+06  3.060408e+05  1.780204e+06  3.128414e+05
# min               0.0  0.000000e+00  0.000000e+00  1.021378e-01  0.000000e+00
# 25%               0.0  1.596244e+06  1.000000e+00  3.000000e-01  3.000000e+01
# 50%               0.0  3.286385e+06  1.000000e+00  3.000000e-01  3.000000e+01
# 75%               0.0  4.694836e+06  1.000000e+00  3.000000e-01  3.000000e+01
# max               0.0  9.859154e+06  8.961248e+06  9.891038e+06  7.541943e+06

# %% [markdown]
# # Image plotting

# %%
img = mpimg.imread(data['Center'][50])

plt.imshow(img)
plt.show()

# %% [markdown]
# # Loading the images into the Dataframe

# %%
data['Center'] = data['Center'].apply(lambda x: mpimg.imread(x))
data['Left'] = data['Left'].apply(lambda x: mpimg.imread(x))
data['Right'] = data['Right'].apply(lambda x: mpimg.imread(x))

# %%
plt.imshow(data['Center'][0])
plt.show()

# %% [markdown]
# # Splitting into X and Y
# ### + 0.20 on left images angles
# ### - 0.20 on right images angles

# %%
images = []
angles = []

for img, angle in zip(data['Center'], data['Steering Angle']):
    images.append(img)
    angles.append(angle)
    
for img, angle in zip(data['Left'], data['Steering Angle']):
    images.append(img)
    angles.append(angle+0.20)
    
for img, angle in zip(data['Right'], data['Steering Angle']):
    images.append(img)
    angles.append(angle-0.20)
    
X = np.array(images)
Y = np.array(angles)

# %%
X.shape
# Out:
# (10248, 160, 320, 3)

# %%
Y.shape
# Out:
# (10248,)

# %% [markdown]
# # Spliting into training and testing sets

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.1)

print("Train len: {} | Test len: {}".format(len(y_train), len(y_test)))
# Out:
# Train len: 9223 | Test len: 1025

# %% [markdown]
# # Dummy Model

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, Flatten, Input
from keras.optimizers import Adam

model = Sequential()

model.add(Flatten(input_shape=[160, 320, 3]))
model.add(Dense(2, activation='relu'))
model.add(Dense(1))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 153600)            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 307202
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 3
# =================================================================
# Total params: 307,205
# Trainable params: 307,205
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
model.compile('adam', loss="mean_squared_error", metrics=["mae"])

model.fit(X_train, y_train, epochs=4, validation_split=0.09)
# Out:
# Train on 8392 samples, validate on 831 samples
# Epoch 1/4
# 8392/8392 [==============================] - 4s - loss: 6.2104 - mean_absolute_error: 0.2223 - val_loss: 0.0277 - val_mean_absolute_error: 0.1399
# Epoch 2/4
# 8392/8392 [==============================] - 3s - loss: 0.0265 - mean_absolute_error: 0.1341 - val_loss: 0.0277 - val_mean_absolute_error: 0.1396
# Epoch 3/4
# 8392/8392 [==============================] - 3s - loss: 0.0265 - mean_absolute_error: 0.1338 - val_loss: 0.0277 - val_mean_absolute_error: 0.1393
# Epoch 4/4
# 8392/8392 [==============================] - 3s - loss: 0.0265 - mean_absolute_error: 0.1335 - val_loss: 0.0277 - val_mean_absolute_error: 0.1391

# %% [markdown]
#  ### Evaluation

# %%
predictions = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(y_test, predictions)
# Out:
# 0.13608208571392591

# %% [markdown]
# ### Saving

# %%
model.save("dummy_model.h5")

# %% [markdown]
# # Dummy CNN

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, Flatten, Input
from keras.optimizers import Adam
from keras.layers import Conv2D, MaxPool2D

inputs = Input([160, 320, 3])


x = Conv2D(32, 7, activation="relu")(inputs)
x = MaxPool2D((2,2))(x)

x = Conv2D(64, 3, activation="relu")(x)
x = MaxPool2D((2,2))(x)

x = Conv2D(128, 3, activation="relu")(x)
x = MaxPool2D((2,2))(x)


x = Conv2D(256, 3, activation="relu")(x)
x = MaxPool2D((2,2))(x)

x = Conv2D(512, 3, activation="relu")(x)
x = Conv2D(512, 3, activation="relu")(x)
x = MaxPool2D((2,2))(x)

x = Flatten()(x)
x = Dense(512, activation="relu")(x)
x = Dense(256, activation="relu")(x)


outs = Dense(1)(x)

model = Model(inputs, outs)

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 160, 320, 3)       0
# _________________________________________________________________
# conv2d_55 (Conv2D)           (None, 154, 314, 32)      4736
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 77, 157, 32)       0
# _________________________________________________________________
# conv2d_56 (Conv2D)           (None, 75, 155, 64)       18496
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 37, 77, 64)        0
# _________________________________________________________________
# conv2d_57 (Conv2D)           (None, 35, 75, 128)       73856
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 17, 37, 128)       0
# _________________________________________________________________
# conv2d_58 (Conv2D)           (None, 15, 35, 256)       295168
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 7, 17, 256)        0
# _________________________________________________________________
# conv2d_59 (Conv2D)           (None, 5, 15, 512)        1180160
# _________________________________________________________________
# conv2d_60 (Conv2D)           (None, 3, 13, 512)        2359808
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 1, 6, 512)         0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 3072)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 512)               1573376
# _________________________________________________________________
# dense_16 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 5,637,185
# Trainable params: 5,637,185
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
model.compile('adam', loss="mean_absolute_error", metrics=["mae"])

model.fit(X_train, y_train, epochs=25, validation_split=0.1)
# Out:
# Train on 8300 samples, validate on 923 samples
# Epoch 1/25
# 8300/8300 [==============================] - 38s - loss: 1.3936 - mean_absolute_error: 1.3936 - val_loss: 0.1246 - val_mean_absolute_error: 0.1246
# Epoch 2/25
# 8300/8300 [==============================] - 37s - loss: 0.1244 - mean_absolute_error: 0.1244 - val_loss: 0.1181 - val_mean_absolute_error: 0.1181
# Epoch 3/25
# 8300/8300 [==============================] - 37s - loss: 0.1192 - mean_absolute_error: 0.1192 - val_loss: 0.1155 - val_mean_absolute_error: 0.1155
# Epoch 4/25
# 8300/8300 [==============================] - 37s - loss: 0.1102 - mean_absolute_error: 0.1102 - val_loss: 0.0998 - val_mean_absolute_error: 0.0998
# Epoch 5/25
# 8300/8300 [==============================] - 36s - loss: 0.1015 - mean_absolute_error: 0.1015 - val_loss: 0.1011 - val_mean_absolute_error: 0.1011
# Epoch 6/25
# 8300/8300 [==============================] - 35s - loss: 0.0948 - mean_absolute_error: 0.0948 - val_loss: 0.0956 - val_mean_absolute_error: 0.0956
# Epoch 7/25
# 8300/8300 [==============================] - 34s - loss: 0.0869 - mean_absolute_error: 0.0869 - val_loss: 0.0772 - val_mean_absolute_error: 0.0772
# Epoch 8/25
# 8300/8300 [==============================] - 33s - loss: 0.0814 - mean_absolute_error: 0.0814 - val_loss: 0.0792 - val_mean_absolute_error: 0.0792
# Epoch 9/25
# 8300/8300 [==============================] - 33s - loss: 0.0735 - mean_absolute_error: 0.0735 - val_loss: 0.0889 - val_mean_absolute_error: 0.0889
# Epoch 10/25
# 8300/8300 [==============================] - 33s - loss: 0.0701 - mean_absolute_error: 0.0701 - val_loss: 0.0730 - val_mean_absolute_error: 0.0730
# Epoch 11/25
# 8300/8300 [==============================] - 33s - loss: 0.0686 - mean_absolute_error: 0.0686 - val_loss: 0.0720 - val_mean_absolute_error: 0.0720
# Epoch 12/25
# 8300/8300 [==============================] - 33s - loss: 0.0612 - mean_absolute_error: 0.0612 - val_loss: 0.0652 - val_mean_absolute_error: 0.0652
# Epoch 13/25
# 8300/8300 [==============================] - 33s - loss: 0.0578 - mean_absolute_error: 0.0578 - val_loss: 0.0647 - val_mean_absolute_error: 0.0647
# Epoch 14/25
# 8300/8300 [==============================] - 33s - loss: 0.0524 - mean_absolute_error: 0.0524 - val_loss: 0.0592 - val_mean_absolute_error: 0.0592
# Epoch 15/25
# 8300/8300 [==============================] - 33s - loss: 0.0514 - mean_absolute_error: 0.0514 - val_loss: 0.0613 - val_mean_absolute_error: 0.0613
# Epoch 16/25
# 8300/8300 [==============================] - 33s - loss: 0.0480 - mean_absolute_error: 0.0480 - val_loss: 0.0625 - val_mean_absolute_error: 0.0625
# Epoch 17/25
# 8300/8300 [==============================] - 33s - loss: 0.0427 - mean_absolute_error: 0.0427 - val_loss: 0.0530 - val_mean_absolute_error: 0.0530
# Epoch 18/25
# 8300/8300 [==============================] - 33s - loss: 0.0417 - mean_absolute_error: 0.0417 - val_loss: 0.0525 - val_mean_absolute_error: 0.0525
# Epoch 19/25
# 8300/8300 [==============================] - 33s - loss: 0.0397 - mean_absolute_error: 0.0397 - val_loss: 0.0550 - val_mean_absolute_error: 0.0550
# Epoch 20/25
# 8300/8300 [==============================] - 33s - loss: 0.0403 - mean_absolute_error: 0.0403 - val_loss: 0.0494 - val_mean_absolute_error: 0.0494
# Epoch 21/25
# 8300/8300 [==============================] - 33s - loss: 0.0366 - mean_absolute_error: 0.0366 - val_loss: 0.0579 - val_mean_absolute_error: 0.0579
# Epoch 22/25
# 8300/8300 [==============================] - 33s - loss: 0.0385 - mean_absolute_error: 0.0385 - val_loss: 0.0438 - val_mean_absolute_error: 0.0438
# Epoch 23/25
# 8300/8300 [==============================] - 32s - loss: 0.0346 - mean_absolute_error: 0.0346 - val_loss: 0.0526 - val_mean_absolute_error: 0.0526
# Epoch 24/25
# 8300/8300 [==============================] - 33s - loss: 0.0360 - mean_absolute_error: 0.0360 - val_loss: 0.0520 - val_mean_absolute_error: 0.0520
# Epoch 25/25
# 8300/8300 [==============================] - 33s - loss: 0.0382 - mean_absolute_error: 0.0382 - val_loss: 0.0520 - val_mean_absolute_error: 0.0520

# %% [markdown]
# ### Evaluation

# %%
from sklearn.metrics import mean_absolute_error

predictions = model.predict(X_test)

mean_absolute_error(y_test, predictions)
# Out:
# 0.05700339352593916

# %% [markdown]
# ### Saving

# %%
model.save("cnn_model.h5")

# %% [markdown]
# # VGG Model

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, Flatten, Input
from keras.optimizers import Adam
from keras.layers import Conv2D, MaxPool2D


inputs = Input([160, 320, 3])

x = Conv2D(32, 7, activation="relu")(inputs)
x = Conv2D(64, 5, activation="relu")(x)
x = MaxPool2D((2,2))(x)

x = Conv2D(128, 3, activation="relu")(x)
x = Conv2D(128, 3, activation="relu")(x)
x = MaxPool2D((2,2))(x)

x = Conv2D(256, 3, activation="relu")(x)
x = Conv2D(256, 3, activation="relu")(x)
x = MaxPool2D((2,2))(x)

x = Conv2D(512, 3, activation="relu")(x)
x = Conv2D(512, 3, activation="relu")(x)
x = MaxPool2D((2,2))(x)

x = Flatten()(x)
#x = Dense(256, activation="relu")(x)
#x = Dense(128, activation="relu")(x)


outputs = Dense(1)(x)

model = Model(inputs, outputs)

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 160, 320, 3)       0
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 154, 314, 32)      4736
# _________________________________________________________________
# conv2d_48 (Conv2D)           (None, 150, 310, 64)      51264
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 75, 155, 64)       0
# _________________________________________________________________
# conv2d_49 (Conv2D)           (None, 73, 153, 128)      73856
# _________________________________________________________________
# conv2d_50 (Conv2D)           (None, 71, 151, 128)      147584
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 35, 75, 128)       0
# _________________________________________________________________
# conv2d_51 (Conv2D)           (None, 33, 73, 256)       295168
# _________________________________________________________________
# conv2d_52 (Conv2D)           (None, 31, 71, 256)       590080
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 15, 35, 256)       0
# _________________________________________________________________
# conv2d_53 (Conv2D)           (None, 13, 33, 512)       1180160
# _________________________________________________________________
# conv2d_54 (Conv2D)           (None, 11, 31, 512)       2359808
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 5, 15, 512)        0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 38400)             0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 38401
# =================================================================
# Total params: 4,741,057
# Trainable params: 4,741,057
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
model.compile('adam', loss="mean_absolute_error", metrics=["mae"])

model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.1)
# Out:
# Train on 8300 samples, validate on 923 samples
# Epoch 1/10
# 8300/8300 [==============================] - 153s - loss: 2.4618 - mean_absolute_error: 2.4618 - val_loss: 0.1267 - val_mean_absolute_error: 0.1267
# Epoch 2/10
# 6976/8300 [========================>.....] - ETA: 22s - loss: 0.1308 - mean_absolute_error: 0.1308
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-811443a9b717> in <module>()
#       1 model.compile('adam', loss="mean_absolute_error", metrics=["mae"])
#       2
# ----> 3 model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.1)
#
# /home/ramdoot/anaconda2/lib/python2.7/site-packages/keras/engine/training.pyc in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1596                               initial_epoch=initial_epoch,
#    1597                               steps_per_epoch=steps_per_epoch,
# -> 1598                               validation_steps=validation_steps)
#    1599
#    1600     def evaluate(self, x, y,
#
# /home/ramdoot/anaconda2/lib/python2.7/site-packages/keras/engine/training.pyc in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1181                     batch_logs['size'] = len(batch_ids)
#    1182                     callbacks.on_batch_begin(batch_index, batch_logs)
# -> 1183                     outs = f(ins_batch)
#    1184                     if not isinstance(outs, list):
#    1185                         outs = [outs]
#
# /home/ramdoot/anaconda2/lib/python2.7/site-packages/keras/backend/tensorflow_backend.pyc in __call__(self, inputs)
#    2271         updated = session.run(self.outputs + [self.updates_op],
#    2272                               feed_dict=feed_dict,
# -> 2273                               **self.session_kwargs)
#    2274         return updated[:len(self.outputs)]
#    2275
#
# /home/ramdoot/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/ramdoot/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1123       results = self._do_run(handle, final_targets, final_fetches,
# -> 1124                              feed_dict_tensor, options, run_metadata)
#    1125     else:
#    1126       results = []
#
# /home/ramdoot/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1321                            options, run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /home/ramdoot/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /home/ramdoot/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1304           return tf_session.TF_Run(session, options,
#    1305                                    feed_dict, fetch_list, target_list,
# -> 1306                                    status, run_metadata)
#    1307
#    1308     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ### Evaluation
